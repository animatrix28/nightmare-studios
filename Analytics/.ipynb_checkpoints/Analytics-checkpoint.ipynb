# %% [markdown]
# Analytics

# %%
file_path = 'RotationAnalytics.txt'

# %%
from collections import defaultdict
import re
import pandas as pd
import matplotlib.pyplot as plt

# %%
def parse_log_to_df(file_path):

    rotation_pattern = re.compile(r"Total rotations at end of level 'Level_(\d+)': (\d+) as of (.+)")

    levels = []
    rotations = []
    timestamps = []

    with open(file_path, 'r') as file:
        for line in file:
            match = rotation_pattern.match(line.strip())
            if match:
                level, rotation, timestamp = match.groups()
                levels.append(int(level))  # Convert level number to integer
                rotations.append(int(rotation))
                timestamps.append(pd.to_datetime(timestamp))

    df = pd.DataFrame({
        'Level': levels,
        'Rotations': rotations,
        'Timestamp': timestamps
    })

    return df

# %%
df = parse_log_to_df(file_path)
df.head()
# Out:
#    Level  Rotations           Timestamp
# 0      1          3 2024-10-24 13:25:30
# 1      2          3 2024-10-24 13:25:40
# 2      3          1 2024-10-24 13:25:44
# 3      3          2 2024-10-24 13:25:48
# 4      3          2 2024-10-24 13:25:53

# %%
average_rotations_df = df.groupby('Level')['Rotations'].mean().reset_index()
average_rotations_df.rename(columns={'Rotations': 'Average Rotations'}, inplace=True)

average_rotations_df
# Out:
#    Level  Average Rotations
# 0      1           2.200000
# 1      2           2.125000
# 2      3           1.875000
# 3      4           6.769231
# 4      5           2.323529

# %%
# Plot for average rotations per level
plt.figure(figsize=(12, 6))
plt.bar(average_rotations_df['Level'], average_rotations_df['Average Rotations'], color='lightgreen', alpha=0.7, label='Average Rotations')
plt.xlabel('Level')
plt.ylabel('Average Rotations')
plt.title('Average Rotations per Level')
plt.legend()
plt.show()

# %%
levels = df['Level'].unique()  # Get unique levels

# Create a plot for each level
for level in levels:
    level_data = df[df['Level'] == level].reset_index(drop=True)  # Filter data for the current level
    plt.figure(figsize=(10, 5))
    plt.bar(level_data.index + 1, level_data['Rotations'], color='skyblue', alpha=0.7)
    plt.xlabel('Try Number')
    plt.ylabel('Rotations')
    plt.title(f'Rotations per Try for Level {level}')
    plt.xticks(level_data.index + 1)  # Set x-ticks as try numbers
    plt.tight_layout()
    plt.show()
